# %%
from domain.Chromosome import Chromosome
from repository.FileRepository import FileRepository
def fitnessFunction(drum, graf):
    cost=0
    for i in range(0, graf.get_length()-1):
        cost += graf.get_cost(drum[i], drum[i+1])
    cost += graf.get_cost(drum[graf.get_length()-1], drum[0])
    return cost

# %%
import random

class GA:
    def __init__(self, param = None, problParam = None):
        self.__param = param
        self.__problParam = problParam
        self.__population = []
        
    @property
    def population(self):
        return self.__population
    
    def initialisation(self):
        for _ in range(0, self.__param['popSize']):
            c = Chromosome(self.__problParam)
            self.__population.append(c)
    
    def evaluation(self):
        for c in self.__population:
            c.fitness = self.__problParam['function'](c.repres, graf)
            
    def bestChromosome(self):
        best = self.__population[0]
        for c in self.__population:
            if (c.fitness < best.fitness):
                best = c
        return best
        
    def worstChromosome(self):
        worst = self.__population[0]
        for c in self.__population:
            if (c.fitness > worst.fitness):
                worst = c
        return worst

    def selection(self):
        pos1 = random.randint(0, self.__param['popSize'] - 1)
        pos2 = random.randint(0, self.__param['popSize'] - 1)
        if self.__population[pos1].fitness < self.__population[pos2].fitness:
            return pos1
        else:
            return pos2 
        
    
    def oneGeneration(self):
        newPopulation = []
        for _ in range(self.__param['popSize']):
            parent1 = self.__population[self.selection()]
            parent2 = self.__population[self.selection()]
            child = parent1.crossover(parent2)
            child.mutation()
            newPopulation.append(child)
        self.__population = newPopulation
        self.evaluation()

    def oneGenerationElitism(self):
        newPopopulation = [self.bestChromosome()]
        for _ in range(self.__param['popSize'] - 1):
            parent1 = self.__population[self.selection()]
            parent2 = self.__population[self.selection()]
            child = parent1.crossover(parent2)
            child.mutation()
            newPopopulation.append(child)
        self.__population = newPopopulation
        self.evaluation()
        
    def oneGenerationSteadyState(self):
        newPopulation = [self.bestChromosome()]
        for _ in range(0, self.__param['popSize'] - 1):
            parent1 = self.__population[self.selection()]
            parent2 = self.__population[self.selection()]
            child = parent1.crossover(parent2)
            child.mutation()
            child.fitness = self.__problParam['function'](child.repres, graf)
            worst = self.worstChromosome()
            if child.fitness > worst.fitness:
                child=worst
            newPopulation.append(child)
        self.__population=newPopulation
        self.evaluation()

# %%
from random import seed 
import os
import copy
#generate seed
seed()

#read net
crtDir =  os.getcwd()
filePath = os.path.join(crtDir, 'data', '50p_hard_01_tsp.in')
fileRepository=FileRepository(filePath)
graf = fileRepository.get_graf()

# GA parameters
gaParam = {'popSize' : 150, 'noGen':200}
# problem parameters
problParam = { 'function' : fitnessFunction, 'noNodes' : graf.get_length()}

# store the best/average solution of each iteration (for a final plot used to anlyse the GA's convergence)

ga = GA(gaParam, problParam)
ga.initialisation() #initialize the population
ga.evaluation() #fitness for every chromosome
ga.oneGenerationSteadyState() 
#ga.oneGenerationElitism()
#ga.oneGeneration()

best_fitness= ga.bestChromosome().fitness
best_representation = copy.deepcopy(ga.bestChromosome().repres)

#generate a number of generations 
for generation in range(gaParam['noGen']):
    #find out the best representation from current generation
    representation = ga.bestChromosome().repres
    fitness = ga.bestChromosome().fitness
    print("Best solution from generation " + str(generation) + " is: " + str(representation) + " with fitness = " + str(fitness)) 
    if fitness < best_fitness :
        best_fitness = fitness
        best_representation.clear()
        best_representation=copy.deepcopy(representation)
    #make a new generation
    ga.oneGenerationSteadyState() 
    #ga.oneGenerationElitism()
    #ga.oneGeneration()
    
print("\n")
print("Best solution from all generation is: " + str([el+1  for el in best_representation]) + " with fitness = " + str(best_fitness))
fileRepository.writeToFile(best_representation, best_fitness)
# Out:
# 8
# Best solution from generation 0 is: [0, 2, 3, 4, 5, 7, 6, 1] with fitness = 492
# Best solution from generation 1 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 2 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 3 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 4 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 5 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 6 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 7 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 8 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 9 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 10 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 11 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 12 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 13 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 14 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 15 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 16 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 17 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 18 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 19 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 20 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 21 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 22 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 23 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 24 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 25 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 26 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 27 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 28 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 29 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 30 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 31 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 32 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 33 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 34 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 35 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 36 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 37 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 38 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 39 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 40 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 41 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 42 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 43 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 44 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 45 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 46 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 47 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 48 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 49 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 50 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 51 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 52 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 53 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 54 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 55 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 56 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 57 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 58 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 59 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 60 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 61 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 62 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 63 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 64 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 65 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 66 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 67 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 68 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 69 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 70 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 71 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 72 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 73 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 74 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 75 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 76 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 77 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 78 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 79 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 80 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 81 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 82 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 83 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 84 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 85 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 86 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 87 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 88 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 89 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 90 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 91 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 92 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 93 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 94 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 95 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 96 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 97 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 98 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 99 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 100 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 101 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 102 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 103 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 104 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 105 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 106 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 107 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 108 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 109 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 110 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 111 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 112 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 113 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 114 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 115 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 116 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 117 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 118 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 119 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 120 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 121 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 122 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 123 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 124 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 125 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 126 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 127 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 128 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 129 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 130 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 131 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 132 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 133 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 134 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 135 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 136 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 137 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 138 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 139 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 140 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 141 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 142 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 143 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 144 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 145 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 146 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 147 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 148 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 149 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 150 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 151 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 152 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 153 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 154 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 155 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 156 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 157 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 158 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 159 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 160 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 161 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 162 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 163 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 164 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 165 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 166 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 167 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 168 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 169 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 170 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 171 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 172 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 173 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 174 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 175 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 176 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 177 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 178 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 179 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 180 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 181 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 182 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 183 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 184 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 185 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 186 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 187 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 188 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 189 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 190 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 191 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 192 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 193 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 194 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 195 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 196 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 197 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 198 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
# Best solution from generation 199 is: [0, 1, 5, 3, 4, 7, 6, 2] with fitness = 474
#
#
# Best solution from all generation is: [1, 2, 6, 4, 5, 8, 7, 3] with fitness = 474
